# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("1.01.+Simple+linear+regression.csv")
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
y = data["GPA"]
x1 = data["SAT"]
x_matrix = x1.values.reshape(-1,1)

# %%
plt.scatter(x_matrix,y)
plt.show()

# %%
reg = LinearRegression().fit(x_matrix,y)
# This is to get R Squared
reg.score(x_matrix,y)
# Out:
# 0.40600391479679754

# %%
# This is to get Coef of the feature
reg.coef_
# Out:
# array([0.00165569])

# %%
# This is to get intercept
reg.intercept_
# Out:
# 0.2750402996602799

# %%
yhat = 0.0017*x1 + 0.2750
plt.scatter(x1,y)
plt.plot(x1,yhat,c="Orange", lw=4)
plt.hlines(y=y.mean(),colors="Green", xmin=1700, xmax=2000, linestyles="--")
plt.show()

# %%
pred_data =  pd.DataFrame([3000, 3200, 3500], columns=['SAT'])
predicted_y = reg.predict(pred_data)
# Out:
# /Users/snarendrtan/Dev01/pythonpoc02/venv/lib/python3.10/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
#pred_data_out = pd.DataFrame()
pred_data_out = pred_data
pred_data_out["Predicted GPA"] = predicted_y

# %%
pred_data_out
# Out:
#     SAT  Predicted GPA
# 0  3000       5.242104
# 1  3200       5.573242
# 2  3500       6.069948
